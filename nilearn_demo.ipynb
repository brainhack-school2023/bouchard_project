# %%
import pandas as pd
import nibabel as nib
from nilearn import datasets, plotting, image
# Out:
# /Users/louis/miniconda3/envs/brainhack_env/lib/python3.7/site-packages/nilearn/__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()

# %%
# Fetch one subject from the ADHD dataset
data = datasets.fetch_development_fmri()
# Out:
# Dataset created in /Users/louis/nilearn_data/development_fmri
#
#
# Dataset created in /Users/louis/nilearn_data/development_fmri/development_fmri
#
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
#  ...done. (2 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
# Downloaded 5832704 of 5880763 bytes (99.2%,    0.0s remaining) ...done. (2 seconds, 0 min)
# ...
#  ...done. (1 seconds, 0 min)
# ...
# Downloaded 6225920 of 6432694 bytes (96.8%,    0.0s remaining) ...done. (2 seconds, 0 min)
# ...

# %%
# Look inside the data
data.keys()
# Out:
# dict_keys(['func', 'confounds', 'phenotypic', 'description'])

# %%
# Check phenotypic info for a patient
data.get("phenotypic")[0]
# Out:
# ('sub-pixar123', 27.06, 'Adult', 'adult', 'F', 'R')

# %%
# Read the data documentation
print(data['description'])#.decode('utf-8'))
# Out:
# The movie watching based brain development dataset (fMRI)
#
#
# Notes
# -----
# This functional MRI dataset is used for teaching how to use
# machine learning to predict age from naturalistic stimuli (movie)
# watching with Nilearn.
#
# The dataset consists of 50 children (ages 3-13) and 33 young adults (ages
# 18-39). This dataset can be used to try to predict who are adults and
# who are children.
#
# The data is downsampled to 4mm resolution for convenience. The original
# data is downloaded from OpenNeuro.
#
# For full information about pre-processing steps on raw-fMRI data, have a look
# at README at https://osf.io/wjtyq/
#
# Full pre-processed data: https://osf.io/5hju4/files/
#
# Raw data can be accessed from : https://openneuro.org/datasets/ds000228/versions/1.0.0
#
# Content
# -------
#     :'func': functional MRI Nifti images (4D) per subject
#     :'confounds': TSV file contain nuisance information per subject
# ...

# %%
# Checkout the location of the functional data that was downloaded
data['func']
# Out:
# ['/Users/louis/nilearn_data/development_fmri/development_fmri/sub-pixar123_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/Users/louis/nilearn_data/development_fmri/development_fmri/sub-pixar124_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/Users/louis/nilearn_data/development_fmri/development_fmri/sub-pixar125_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/Users/louis/nilearn_data/development_fmri/development_fmri/sub-pixar126_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/Users/louis/nilearn_data/development_fmri/development_fmri/sub-pixar127_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/Users/louis/nilearn_data/development_fmri/development_fmri/sub-pixar128_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/Users/louis/nilearn_data/development_fmri/development_fmri/sub-pixar129_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
# ...

# %%
# Load the functional image
img = nib.load(data['func'][0])

# %%
# Take a look at the first time point
plotting.view_img(image.index_img(img, 2))
# Out:
# /Users/louis/miniconda3/envs/brainhack_env/lib/python3.7/site-packages/nilearn/plotting/html_stat_map.py:113: UserWarning: Threshold given was 1e-06, but the data has no values below -116.05355072021484.
#   data.min()))
# /Users/louis/miniconda3/envs/brainhack_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:755: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
# ...

# %%
# Checkout the confounds of the data
confounds = pd.read_csv(data['confounds'][0], sep='\t')

# %%
confounds.head()
# Out:
#     trans_x   trans_y   trans_z     rot_x     rot_y     rot_z  \
# 0 -0.000233 -0.076885  0.062321  0.000732  0.000352  0.000841
# 1 -0.006187 -0.078395  0.056773  0.000112  0.000187  0.000775
# 2 -0.000227 -0.069893  0.083102  0.000143  0.000364  0.000716
# 3  0.002492 -0.074707  0.060337  0.000202  0.000818  0.000681
# 4 -0.000226 -0.084204  0.085079  0.000183  0.000548  0.000682
#
#    framewise_displacement  a_comp_cor_00  a_comp_cor_01  a_comp_cor_02  \
# 0                0.000000      -0.099871      -0.007286       0.001780
# 1                0.055543      -0.019437      -0.042308       0.016735
# 2                0.054112       0.009096      -0.053206      -0.030388
# 3                0.057667       0.060195      -0.083195       0.003578
# 4                0.051438       0.049833      -0.089819      -0.020825
#
#    a_comp_cor_03  a_comp_cor_04  a_comp_cor_05         csf  white_matter
# 0      -0.008073       0.030945      -0.022393  439.699409    451.645460
# ...
