# %%
from nilearn.plotting import view_img
from nilearn import datasets
from nilearn import plotting
# Out:
# /Users/louis/miniconda3/envs/brainhack_env/lib/python3.7/site-packages/nilearn/__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()

# %% [markdown]
# # Fetch atlases

# %% [markdown]
# ## Schaefer atlas

# %%
atlas = datasets.fetch_atlas_schaefer_2018()
# Out:
# Dataset created in /Users/louis/nilearn_data/schaefer_2018
#
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)

# %%
#plot a static map
plotting.plot_roi(atlas.maps)

# %%
#plot an interactive map
plotting.view_img(atlas.maps)
# Out:
# /Users/louis/miniconda3/envs/brainhack_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:755: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
# ...

# %% [markdown]
# ## Fetch and view three atlases of your choice from nilearn.datasets

# %% [markdown]
# You may select any 3 atlases from nilearn.datasets. Fetch and view the atlases using the above code as an example. Check out the documentation for `nilearn.plotting` at https://nilearn.github.io/stable/plotting/index.html to try different viewing methods, edit colours, change viewing options etc.

# %%
# Import extra atlas
atlas_2 = datasets.fetch_atlas_pauli_2017(version='det')
# Out:
# ...
#  ...done. (6 seconds, 0 min)

# %%
#plot a static map
plotting.plot_roi(atlas_2.maps,display_mode='ortho')

# %%
#plot an interactive map
plotting.view_img(atlas_2.maps, threshold=2)
# Out:
# /Users/louis/miniconda3/envs/brainhack_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:755: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
# ...

# %%
# Plot 2d projections of an ROI/mask image
plotting.plot_epi(atlas_2.maps)

# %%
# import second atlas
atlas_3 = datasets.fetch_atlas_aal()
# Out:
# Dataset created in /Users/louis/nilearn_data/aal_SPM12
#
# ...
#  ...done. (2 seconds, 0 min)
# Extracting data from /Users/louis/nilearn_data/aal_SPM12/e2ab16a3db262dc4f9f7c3870f71cb7e/aal_for_SPM12.tar.gz..... done.

# %%
#plot stat map
display = plotting.plot_stat_map(atlas_3.maps,display_mode='yx')

# %%
#plot an image of the atlas maps
plotting.view_img(atlas_3.maps, threshold=1)
# Out:
# /Users/louis/miniconda3/envs/brainhack_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:755: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /Users/louis/miniconda3/envs/brainhack_env/lib/python3.7/site-packages/nilearn/image/resampling.py:597: UserWarning: Casting data from int32 to float32
#   warnings.warn(f"Casting data from {data.dtype.name} to {aux}")
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
# ...

# %%
# Download atlas #3
atlas_4 = datasets.fetch_atlas_aal('SPM5')
# Out:
# Dataset created in /Users/louis/nilearn_data/aal_SPM5
#
# ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /Users/louis/nilearn_data/aal_SPM5/ec7ceed921fbd7f374d16492ef5a40f3/aal_for_SPM5.zip..... done.

# %%
# Plot an stat map
display = plotting.plot_stat_map(atlas_3.maps,display_mode='x')

# %%
# Plot an stat map
display = plotting.plot_stat_map(atlas_3.maps,display_mode='tiled')

# %%
# Plot EPI image
display = plotting.plot_epi(atlas_3.maps,display_mode='tiled')

# %% [markdown]
# # Compare and discuss

# %% [markdown]
# Compare the atlas parcellations and discuss your observations below. What might be some reasons that parcellation could affect your functional connectivity results?

# %% [markdown]
# From what I understood brain parcellation is basically a way to condense information (reduce dimensionality, like PCA) and thus it could clearly affect the results by removing some useful parts of the brain, not concentring on some active outliers parts, etc.
# It helps us visualyze and analyze the brain since we study distinct partitions of the brain instead of directly trying to understand this whole interconnected thing.
#
# The different atlases define the regions very differently and thus studies different "actions"(?) (i.e. I assume we may use specific parcellations for studying the visual cortex vs. someone talking?). Some atlases completely omit lots of regions whereas others split the whole brain in subsections, which should surely lead to very different functional connectivity results.
